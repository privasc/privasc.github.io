# %%
import pandas as pd
import datetime
import utm

# %%
# Set holidays for 2021
holidays = []

holidays.append(datetime.datetime(2021, 1, 1))
holidays.append(datetime.datetime(2021, 1, 6))
holidays.append(datetime.datetime(2021, 3, 19))
holidays.append(datetime.datetime(2021, 4, 1))
holidays.append(datetime.datetime(2021, 4, 2))
holidays.append(datetime.datetime(2021, 5, 1))
holidays.append(datetime.datetime(2021, 5, 3))
holidays.append(datetime.datetime(2021, 10, 12))
holidays.append(datetime.datetime(2021, 11, 1))
holidays.append(datetime.datetime(2021, 12, 6))
holidays.append(datetime.datetime(2021, 12, 8))
holidays.append(datetime.datetime(2021, 12, 25))
holidays.append(datetime.datetime(2021, 5, 15))
holidays.append(datetime.datetime(2021, 11, 9))

# %%
# Load dataset
file_name = '2021_Accidentalidad.csv'

dt = pd.read_csv('2021_Accidentalidad.csv',sep=';', decimal=",")
dt.head()
# Out:
#   num_expediente       fecha     hora                         localizacion  \
# 0    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 1    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 2    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 3    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 4    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
#
#   numero            distrito           tipo_accidente estado_meteorológico  \
# 0     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 1     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 2     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 3     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 4     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
#
#   tipo_vehiculo tipo_persona       rango_edad         sexo lesividad  \
# 0       Turismo    Conductor      Desconocido  Desconocido       NaN
# 1       Turismo    Conductor  De 30 a 34 años        Mujer        14
# 2       Turismo    Conductor  De 35 a 39 años       Hombre         7
# 3       Turismo     Pasajero  De 10 a 14 años       Hombre        14
# 4       Turismo     Pasajero  De 35 a 39 años        Mujer        14
#
#    coordenada_x_utm  coordenada_y_utm positiva_alcohol  positiva_droga
# 0          444926.3        4470383.11                N             NaN
# 1          444926.3        4470383.11                N             NaN
# 2          444926.3        4470383.11                N             NaN
# 3          444926.3        4470383.11                N             NaN
# 4          444926.3        4470383.11                N             NaN

# %%
# Transform UTM coordinates to geographic. 
# Madrid's UTM zone is 30T.
geographic = dt.apply(
    lambda row : utm.to_latlon(row['coordenada_x_utm'],
                               row['coordenada_y_utm'],
                               30,'T'),
    axis=1
).apply(pd.Series)
geographic.columns = ('lat', 'lon')
dt = pd.concat([dt, geographic], axis=1)
dt.head()
# Out:
#   num_expediente       fecha     hora                         localizacion  \
# 0    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 1    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 2    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 3    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
# 4    2020S019534  01/01/2021  4:30:00  AVDA. PABLO NERUDA / CALL. LEONESES
#
#   numero            distrito           tipo_accidente estado_meteorológico  \
# 0     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 1     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 2     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 3     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 4     57  PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
#
#   tipo_vehiculo tipo_persona       rango_edad         sexo lesividad  \
# 0       Turismo    Conductor      Desconocido  Desconocido       NaN
# 1       Turismo    Conductor  De 30 a 34 años        Mujer        14
# 2       Turismo    Conductor  De 35 a 39 años       Hombre         7
# 3       Turismo     Pasajero  De 10 a 14 años       Hombre        14
# 4       Turismo     Pasajero  De 35 a 39 años        Mujer        14
#
#    coordenada_x_utm  coordenada_y_utm positiva_alcohol  positiva_droga  \
# 0          444926.3        4470383.11                N             NaN
# 1          444926.3        4470383.11                N             NaN
# 2          444926.3        4470383.11                N             NaN
# 3          444926.3        4470383.11                N             NaN
# 4          444926.3        4470383.11                N             NaN
#
#          lat       lon
# 0  40.382218 -3.648825
# 1  40.382218 -3.648825
# 2  40.382218 -3.648825
# 3  40.382218 -3.648825
# 4  40.382218 -3.648825

# %%
# Generate datetime of the accident.
dt['datetime'] = pd.to_datetime(dt['fecha'] + " " + dt['hora'], format="%d/%m/%Y %H:%M:%S")
# Extract the hour of the accident.
dt['hour_interval'] = dt['datetime'].dt.hour.floordiv(4)
# Extract the weekday of the accident (Monday=0 to Sunday=6).
dt['weekday'] = dt['datetime'].dt.dayofweek
# Check whether the accident happened on a bank holiday.
dt['holidays'] = pd.to_datetime(dt['fecha'], format="%d/%m/%Y").isin(holidays)
# Check whether the accident happened on a weekend.
dt['weekend'] = dt['weekday'].isin([5,6])
# Check whether the accident happened on a workday.
dt['workdays'] = (~(dt['weekend'] | dt['holidays'])).astype(int)
dt
# Out:
#       num_expediente       fecha      hora  \
# 0        2020S019534  01/01/2021   4:30:00
# 1        2020S019534  01/01/2021   4:30:00
# 2        2020S019534  01/01/2021   4:30:00
# 3        2020S019534  01/01/2021   4:30:00
# 4        2020S019534  01/01/2021   4:30:00
# ...              ...         ...       ...
# 24459    2021S015803  31/08/2021  13:50:00
# 24460    2021S015803  31/08/2021  13:50:00
# 24461    2021S016898  31/08/2021  22:56:00
# 24462    2021S016898  31/08/2021  22:56:00
# 24463    2021S016898  31/08/2021  22:56:00
#
#                                             localizacion numero  \
# 0                    AVDA. PABLO NERUDA / CALL. LEONESES     57
# 1                    AVDA. PABLO NERUDA / CALL. LEONESES     57
# 2                    AVDA. PABLO NERUDA / CALL. LEONESES     57
# 3                    AVDA. PABLO NERUDA / CALL. LEONESES     57
# 4                    AVDA. PABLO NERUDA / CALL. LEONESES     57
# ...                                                  ...    ...
# 24459                           CALL. MARCELO USERA, 168    168
# 24460                           CALL. MARCELO USERA, 168    168
# 24461  CALL. CAMINO DE LOS VINATEROS / CALL. CORREGID...      1
# 24462  CALL. CAMINO DE LOS VINATEROS / CALL. CORREGID...      1
# 24463  CALL. CAMINO DE LOS VINATEROS / CALL. CORREGID...      1
#
#                  distrito           tipo_accidente estado_meteorológico  \
# 0      PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 1      PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 2      PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 3      PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# 4      PUENTE DE VALLECAS  Colisión fronto-lateral            Despejado
# ...                   ...                      ...                  ...
# 24459               USERA                  Alcance            Despejado
# 24460               USERA                  Alcance            Despejado
# 24461           MORATALAZ  Colisión fronto-lateral            Despejado
# 24462           MORATALAZ  Colisión fronto-lateral            Despejado
# 24463           MORATALAZ  Colisión fronto-lateral            Despejado
#
#                  tipo_vehiculo tipo_persona  ... positiva_droga        lat  \
# 0                      Turismo    Conductor  ...            NaN  40.382218
# 1                      Turismo    Conductor  ...            NaN  40.382218
# 2                      Turismo    Conductor  ...            NaN  40.382218
# 3                      Turismo     Pasajero  ...            NaN  40.382218
# 4                      Turismo     Pasajero  ...            NaN  40.382218
# ...                        ...          ...  ...            ...        ...
# 24459                  Turismo    Conductor  ...            NaN  40.385444
# 24460                  Turismo     Pasajero  ...            NaN  40.385444
# 24461  Motocicleta hasta 125cc    Conductor  ...            NaN  40.410951
# 24462                  Turismo    Conductor  ...            NaN  40.410951
# 24463                  Turismo     Pasajero  ...            NaN  40.410951
#
#             lon            datetime  hour weekday  holidays  weekend  \
# 0     -3.648825 2021-01-01 04:30:00     4       4      True    False
# 1     -3.648825 2021-01-01 04:30:00     4       4      True    False
# 2     -3.648825 2021-01-01 04:30:00     4       4      True    False
# 3     -3.648825 2021-01-01 04:30:00     4       4      True    False
# 4     -3.648825 2021-01-01 04:30:00     4       4      True    False
# ...         ...                 ...   ...     ...       ...      ...
# 24459 -3.715390 2021-08-31 13:50:00    13       1     False    False
# 24460 -3.715390 2021-08-31 13:50:00    13       1     False    False
# 24461 -3.660492 2021-08-31 22:56:00    22       1     False    False
# 24462 -3.660492 2021-08-31 22:56:00    22       1     False    False
# 24463 -3.660492 2021-08-31 22:56:00    22       1     False    False
#
#        workdays hour_interval
# 0             0             1
# 1             0             1
# 2             0             1
# 3             0             1
# 4             0             1
# ...         ...           ...
# 24459         1             3
# 24460         1             3
# 24461         1             5
# 24462         1             5
# 24463         1             5
#
# [24464 rows x 26 columns]

# %%
# Save data.
idx = ['lat', 'lon', 'hour_interval', 'workdays']
dt[idx].to_csv('doc.csv', index=False ,na_rep="NULL")
